# %%
import numpy as np

data = np.load('/home/arawa/Shabaz_simulation/figure_7_ak.npy')
data.shape
# Out:
# (128, 128, 128)

# %%
coords = (data != 0).nonzero()

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(coords[0], coords[1], coords[2], s=0.05)
